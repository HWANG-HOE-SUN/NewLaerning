# %% [markdown]
# <a href="https://colab.research.google.com/github/HWANG-HOE-SUN/NewLaerning/blob/master/GAN/Chap1/GAN_Chap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 출처 : https://m.blog.naver.com/euleekwon/221557899873
# GAN 제발 이해하자

# %% [markdown]
# ![Gan_Chap1-1.png](data:image/png;base64,...)

# %% [markdown]
# GAN은 G(생성자) 와 D(구분자,식별자)의 적대적 경쟁 관계이다.
#
# G가 비지도학습(Unsupervised Learning)으로 Noise가득한 쓰레기 더미에서 데이터를 생성해내고, 이 Data와 Real_Data를 가지고 D가 구별해낸다(분류문제)
#
# 이 과정을 반복(분류1번 = 1 에포크)함으로 점점 실제에 가까운 가짜를 G가 만들 수 있게 된다.
